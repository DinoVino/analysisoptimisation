# %% [markdown]
# # Analysis Optimisation

# %%
import pandas
import sklearn

# %%
print(sklearn)
print(pandas)
# Out:
# <module 'sklearn' from '/home/ursavin/Repositories/analysisoptimisation/.venv/lib/python3.13/site-packages/sklearn/__init__.py'>
# <module 'pandas' from '/home/ursavin/Repositories/analysisoptimisation/.venv/lib/python3.13/site-packages/pandas/__init__.py'>
